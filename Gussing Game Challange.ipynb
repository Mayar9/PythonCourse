# %%
from random import randint

randomNum = randint(0,100)
userInput = input('Enter your number within 1 and 100 :')
#print(randomNum, userInput)
#type(int(userInput))
userInput_int = int(userInput)

if userInput_int < 1 or userInput_int > 100 :
    print('OUT OF BOUNDS')
# Out:
# OUT OF BOUNDS
